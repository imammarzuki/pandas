# %% [markdown]
# Membuat dataframe dari array

# %%
import pandas as pd
import numpy as np
data = np.random.random(size=(6,4))
df = pd.DataFrame(data=data, columns=["A", "B", "C", "D"])

# %%
df
# Out:
#           A         B         C         D
# 0  0.720258  0.992133  0.252867  0.357397
# 1  0.256398  0.402624  0.718107  0.749129
# 2  0.093180  0.631983  0.926854  0.545172
# 3  0.736595  0.028599  0.983183  0.807897
# 4  0.144888  0.688971  0.192125  0.125941
# 5  0.036005  0.873407  0.637330  0.309228

# %% [markdown]
# Membuat dataframe dari dictionary

# %%
df = pd.DataFrame(data={"A": [1, 2, 3], "B" : ["Bandung", "Jakarta", "Denpasar"]})

#atau bisa juga row by row
data = [{"A" : 1, "B": "Bandung"}, {"A" : 2, "B": "Jakarta"}, {"A" : 3, "B": "Denpasar"}]
df = pd.DataFrame(data=data)

# %% [markdown]
# Menyimpan dataframe

# %%
df.to_csv("namafile.csv")
